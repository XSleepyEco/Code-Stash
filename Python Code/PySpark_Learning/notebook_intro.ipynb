# %%
import pandas as pd
import pyspark

# %%
import os
#os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-11.0.31.11-hotspot"  # adjust to your actual path
#os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-25.0.2.10-hotspot"
os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-17.0.19.10-hotspot"
os.environ["PATH"] = os.environ["JAVA_HOME"] + r"\bin;" + os.environ["PATH"]
os.environ["SPARK_LOCAL_IP"] = "127.0.0.1"
os.environ["SPARK_LOCAL_HOSTNAME"] = "localhost"

# %%
import subprocess
result = subprocess.run(["java", "-version"], capture_output=True, text=True)
print(result.stderr)  # java -version outputs to stderr
# Out:
# openjdk version "17.0.19" 2026-04-21
# OpenJDK Runtime Environment Temurin-17.0.19+10 (build 17.0.19+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.19+10 (build 17.0.19+10, mixed mode, sharing)

# %%
pd.read_csv('Water Quality - Every Drop Matters\Cities1.csv')
# Out:
#                   City                Region                   Country  \
# 0        New York City              New York  United States of America
# 1     Washington, D.C.  District of Columbia  United States of America
# 2        San Francisco            California  United States of America
# 3               Berlin                   NaN                   Germany
# 4          Los Angeles            California  United States of America
# ...                ...                   ...                       ...
# 3958             Yanbu       Medina Province              Saudi Arabia
# 3959           Cordoba             Andalusia                     Spain
# 3960               Vic             Catalonia                     Spain
# 3961           Segovia      Castile and Leon                     Spain
# 3962       Zamora city      Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
from pyspark.sql import SparkSession

# %%
#spark = SparkSession.builder.appName('Practise').getOrCreate() #Creates a spark session with the name 'Practise'

spark = SparkSession.builder.master("local").appName("Practise").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://localhost:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# You can see how many clussters are available but as this is local we get only one

# %%
# ABFS Path for the file
abfs_path = "C:\GitHub Repos\Code-Stash\Python Code\PySpark_Learning"
print(abfs_path + '\Water Quality - Every Drop Matters\Cities1.csv')
# Out:
# C:\GitHub Repos\Code-Stash\Python Code\PySpark_Learning\Water Quality - Every Drop Matters\Cities1.csv

# %%
#df = spark.read.csv('Gibberish') 
df_pyspark = spark.read.csv('Water Quality - Every Drop Matters\Cities1.csv', header=True)

# %%
df_pyspark #will show you the structure of the data frame.
# Out:
# DataFrame[City: string, Region: string, Country: string, AirQuality: string, WaterPollution: string]

# %%
df_pyspark.show()
# Out:
# +----------------+--------------------+--------------------+-----------+--------------+
# |            City|              Region|             Country| AirQuality|WaterPollution|
# +----------------+--------------------+--------------------+-----------+--------------+
# |   New York City|            New York|United States of ...|46.81603774|    49.5049505|
# |Washington, D.C.|District of Columbia|United States of ...|66.12903226|   49.10714286|
# |   San Francisco|          California|United States of ...|60.51401869|            43|
# |          Berlin|                NULL|             Germany|62.36413043|   28.61271676|
# |     Los Angeles|          California|United States of ...|36.62162162|   61.29943503|
# |            Bern|      Canton of Bern|         Switzerland|94.31818182|          12.5|
# |          Geneva|    Canton of Geneva|         Switzerland|71.53846154|   17.37288136|
# |          Zurich|    Canton of Zurich|         Switzerland|83.80952381|   10.71428571|
# ...

# %% [markdown]
# "show()" shows the items in the data frame

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- City: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- AirQuality: string (nullable = true)
#  |-- WaterPollution: string (nullable = true)

# %% [markdown]
# Shows the table schema of the dataframe.
